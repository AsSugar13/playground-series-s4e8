# %%
# !optuna-dashboard sqlite:///fcnn-study_matthews.db --port 8080
# Out:
# Listening on http://127.0.0.1:8080/
# Hit Ctrl-C to quit.
#
# 127.0.0.1 - - [27/Aug/2024 08:50:08] "GET /dashboard/studies/5/trialTable HTTP/1.1" 200 4145
# 127.0.0.1 - - [27/Aug/2024 08:50:08] "GET /api/studies/5?after=19 HTTP/1.1" 200 8229
# 127.0.0.1 - - [27/Aug/2024 08:50:09] "GET /api/studies/5?after=0 HTTP/1.1" 200 59890
# 127.0.0.1 - - [27/Aug/2024 08:50:09] "GET /api/meta HTTP/1.1" 200 63
# 127.0.0.1 - - [27/Aug/2024 08:50:10] "GET /api/studies/5?after=19 HTTP/1.1" 200 10954
# 127.0.0.1 - - [27/Aug/2024 08:50:12] "GET /api/studies/5?after=20 HTTP/1.1" 200 8234
# 127.0.0.1 - - [27/Aug/2024 08:50:14] "GET /api/studies/5?after=20 HTTP/1.1" 200 8234
# 127.0.0.1 - - [27/Aug/2024 08:50:16] "GET /api/studies/5?after=20 HTTP/1.1" 200 8234
# 127.0.0.1 - - [27/Aug/2024 08:50:19] "GET /api/studies/5?after=20 HTTP/1.1" 200 8234
# 127.0.0.1 - - [27/Aug/2024 08:50:20] "GET /api/studies/5?after=19 HTTP/1.1" 200 10954
# ...

# %%
# !ls
